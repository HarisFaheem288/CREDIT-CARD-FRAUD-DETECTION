# %%
import pandas as pd
df=pd.read_csv("fraud.csv")
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0       6/21/2020 12:14  2.291160e+15
# 1           1       6/21/2020 12:14  3.573030e+15
# 2           2       6/21/2020 12:14  3.598220e+15
# 3           3       6/21/2020 12:15  3.591920e+15
# 4           4       6/21/2020 12:15  3.526830e+15
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# 1  Williams      F             3638 Marsh Union  ...  40.3207 -110.4360
# ...

# %%
df = df.drop(columns=['Unnamed: 0', 'first', 'last', 'street', 'trans_date_trans_time', 'dob', 'trans_num'])

# %%
df
# Out:
#               cc_num                              merchant        category  \
# 0       2.291160e+15                 fraud_Kirlin and Sons   personal_care
# 1       3.573030e+15                  fraud_Sporer-Keebler   personal_care
# 2       3.598220e+15  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3       3.591920e+15                     fraud_Haley Group        misc_pos
# 4       3.526830e+15                 fraud_Johnston-Casper          travel
# ...              ...                                   ...             ...
# 555714  3.056060e+13                 fraud_Reilly and Sons  health_fitness
# 555715  3.556610e+15                  fraud_Hoppe-Parisian       kids_pets
# 555716  6.011720e+15                       fraud_Rau-Robel       kids_pets
# 555717  4.079770e+12                 fraud_Breitenberg LLC          travel
# 555718  4.170690e+15                     fraud_Dare-Marvin   entertainment
#
# ...

# %%
print(df.isnull().sum())
# Out:
# cc_num        0
# merchant      0
# category      0
# amt           0
# gender        0
# city          0
# state         0
# zip           0
# lat           0
# long          0
# city_pop      0
# job           0
# unix_time     0
# merch_lat     0
# merch_long    0
# is_fraud      0
# dtype: int64

# %%
df = pd.get_dummies(df, columns=['city','merchant', 'category', 'gender', 'job','state'], drop_first=True)

# %%
df
# Out:
#               cc_num     amt    zip      lat      long  city_pop   unix_time  \
# 0       2.291160e+15    2.86  29209  33.9659  -80.9355    333497  1371816865
# 1       3.573030e+15   29.84  84002  40.3207 -110.4360       302  1371816873
# 2       3.598220e+15   41.28  11710  40.6729  -73.5365     34496  1371816893
# 3       3.591920e+15   60.05  32780  28.5697  -80.8191     54767  1371816915
# 4       3.526830e+15    3.19  49632  44.2529  -85.0170      1126  1371816917
# ...              ...     ...    ...      ...       ...       ...         ...
# 555714  3.056060e+13   43.77  63453  40.4931  -91.8912       519  1388534347
# 555715  3.556610e+15  111.84  77566  29.0393  -95.4401     28739  1388534349
# 555716  6.011720e+15   86.88  99323  46.1966 -118.9017      3684  1388534355
# 555717  4.079770e+12    7.99  83643  44.6255 -116.4493       129  1388534364
# 555718  4.170690e+15   38.13  73034  35.6665  -97.4798    116001  1388534374
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Columns: 2090 entries, cc_num to state_WY
# dtypes: bool(2080), float64(6), int64(4)
# memory usage: 1.1 GB

# %%
from sklearn.model_selection import train_test_split
x = df.drop('is_fraud', axis=1)  
y = df.is_fraud    
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# C:\Users\VICTUS\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score 
y_pred = model.predict(x_test)
print("Logistic Regression Accuracy is:", accuracy_score(y_test, y_pred))
# Out:
# Logistic Regression Accuracy is: 0.9967519614194198

# %%
from sklearn.tree import DecisionTreeClassifier
model1 = DecisionTreeClassifier(random_state=42)
model1.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred1 = model1.predict(x_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred1))
# Out:
# Decision Tree Accuracy: 0.9974177643417549

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(n_estimators=2, random_state=42)
model2.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=2, random_state=42)

# %%
y_pred2 = model2.predict(x_test)
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred2))
# Out:
# Random Forest Accuracy: 0.9968689267976679
